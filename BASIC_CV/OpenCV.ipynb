# %% [markdown]
# # OPEN-CV OPERATIONS ON IMAGE

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('../DATA/00-puppy.jpg')   # already present in numpy darray format no need to conversion

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img_dummy = cv2.imread('DATA/faltu_path/dummy.jpg')   # No error shows, for the wrong path or not available files.

# %%
type(img_dummy)     # always check the type to double check - NoneType
# Out:
# NoneType

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)     # cv2 has different color channel --> BGR

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)
